# %% [markdown]
# <h1 align='center'>  <font size = '6' color='red'> Assignment 2 (Questions) <font> </h1>
#
#
#
# ![login-logo-ps.png](attachment:login-logo-ps.png)
#
#
#
# <br>
# <!-- <center align="left"> Developed for the MSc Program in Data Science  </center> -->
#
#
#   <center align="left">    <center align="left"><center align="left"> <font color='dark blue'><font style= 'bold' size='3' color='dark'>   Instructors: Dr. Khaled Mohamad, Dr. Aziza Aipenova, and Dr. Dauren Ayazbayev <font> </center>

# %% [markdown]
# ## Total [10 Marks]

# %%
#Import all needed libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Load the dataset "tips" from seaborn library (0.5 Mark)

tips = sns.load_dataset("tips")

print(tips)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
#Show the five number summary (0.5 Mark)

tips = sns.load_dataset("tips")

total_bill = tips['total_bill']

minimum = np.min(total_bill)
q1 = np.percentile(total_bill, 25)
median = np.median(total_bill)
q3 = np.percentile(total_bill, 75)
maximum = np.max(total_bill)

print(f"Min: {minimum}")
print(f"Q1: {q1}")
print(f"Median: {median}")
print(f"Q3: {q3}")
print(f"Max: {maximum}")
# Out:
# Min: 3.07
# Q1: 13.3475
# Median: 17.795
# Q3: 24.127499999999998
# Max: 50.81

# %%
#Draw horizontal boxplot for total bill using matplotlib lib (0.5 Mark)

tips = sns.load_dataset("tips")

total_bill_data = tips['total_bill']

plt.figure(figsize=(8, 6))
plt.boxplot(total_bill_data, vert=False)

plt.xlabel('Total Bill')
plt.title('Horizontal Boxplot')

plt.show()

# %%
#Draw a vertical boxplot for tip grouped by sex using seaborn lib  (1 Mark)

tips = sns.load_dataset("tips")

plt.figure(figsize=(8, 6))  # Optional: Adjust the figure size
sns.boxplot(x='sex', y='tip', data=tips)

plt.xlabel('Sex')
plt.ylabel('Tip')
plt.title('Vertical Boxplot')

plt.show()

# %%
#Draw a scatter plot with regression line between total bill and tip. It should be two graph , one for male and the second with male

tips = sns.load_dataset("tips")

male_tips = tips[tips['sex'] == 'Male']
female_tips = tips[tips['sex'] == 'Female']
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
sns.regplot(x='total_bill', y='tip', data=male_tips, color='blue')
plt.title('Male')

plt.subplot(1, 2, 2)
sns.regplot(x='total_bill', y='tip', data=female_tips, color='green')
plt.title('Female')

plt.tight_layout()

plt.show()
#(1 Mark)

# %%
#Draw scatter plot matrix for your data (1 Mark)

tips = sns.load_dataset("tips")

sns.pairplot(tips)

plt.show()

# %% [markdown]
# ### Correlation Matrix
#
# Draw the heat map for the dataset.

# %%
# This step required to drop the qualtitive columns in your dataset. It has been done for you

# %%
quantitative_columns = tips[["total_bill", "tip", "size"]]

correlation_matrix = quantitative_columns.corr()

correlation_coefficient = correlation_matrix.loc['total_bill', 'tip']

print(f"The correlation coefficient between total_bill and tip is: {correlation_coefficient}")
# Out:
# The correlation coefficient between total_bill and tip is: 0.6757341092113647

# %%
#Draw the heatmap (1 Mark)
correlation_matrix = tips[["total_bill", "tip", "size"]].corr()

sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")

plt.title("Correlation Heatmap")

plt.show()

# %%
#Draw the heatmap and make the size of the facelet 8x8 and change the color cmap to "BrBG"  (0.5 Mark)

correlation_matrix = tips[["total_bill", "tip", "size"]].corr()

plt.figure(figsize=(8, 8))

sns.heatmap(correlation_matrix, annot=True, cmap='BrBG', fmt=".2f")

plt.title("Correlation Heatmap")

plt.show()

# %%
#Draw histrogram for total bill and include the following: bins = 10, edcolor, labels (0.5 Mark)

plt.hist(tips['total_bill'], bins = 10, edgecolor='black')

plt.xlabel('Total Bill')
plt.ylabel('Frequency')
plt.title('Total Bill Histogram')

plt.show()

# %%
# Draw a Pie chart using the following information. You need to include the following: colors, explode option, autopct option
#(0.5 Mark)

categories = ['Category A', 'Category B', 'Category C', 'Category D']
sizes = [30, 25, 20, 25]
colors = ['#ff9999','#66b3ff','#99ff99','#ffcc99']
explode = (0.1, 0, 0, 0) 

plt.pie(sizes, colors=colors, labels=categories, autopct='%1.1f%%', startangle=90, explode=explode)

plt.axis('equal')

plt.title('Sample Pie Chart')

plt.show()

# %%
# Add the following options to the above pie graph and you need to comment on them: startangle=120, shadow=True
categories = ['Category A', 'Category B', 'Category C', 'Category D']
sizes = [30, 25, 20, 25]
colors = ['#ff9999','#66b3ff','#99ff99','#ffcc99']
explode = (0.1, 0, 0, 0)

plt.pie(sizes, colors=colors, labels=categories, autopct='%1.1f%%', startangle=120, explode=explode, shadow=True)

plt.axis('equal')

plt.title('Sample Pie Chart')


plt.show()

#(0.5 Mark)

# %%
#Draw one line plot for the function sin and sinh. You need to add title, labels and legend (0.5 Mark)

#Use the follwoing x varaibles
x = np.linspace(-np.pi, np.pi, 200) # this code is going to help you to creat an array with 200 points fom - pi to pi
#To help you you may use the following functions
y1= np.sin(x)
y2= np.sinh(x)

plt.plot(x, y1, label='sin(x)', color='blue')
plt.plot(x, y2, label='sinh(x)', color='red')

plt.title('Line Plot of sin(x) and sinh(x)')
plt.xlabel('x')
plt.ylabel('y')

plt.legend()

plt.show()

# %%
#Draw one line plot for the function Cos and Cosh. You need to add title, labels and legend (0.5 Mark)

#Use the follwoing x varaibles
x = np.linspace(-np.pi, np.pi, 200) # this code is going to help you to creat an array with 200 points fom - pi to pi

#To help you you may use the following functions
y3= np.cos(x)
y4= np.cosh(x)

plt.plot(x, y3, label='cos(x)', color='blue')
plt.plot(x, y4, label='cosh(x)', color='red')

plt.title('Line Plot of cos(x) and cosh(x)')
plt.xlabel('x')
plt.ylabel('y')

plt.legend()

plt.show()
